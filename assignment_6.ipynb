# %%
'''
Author: Ismael Bah
Purpose:
    - Differentiate between categorical and non-categoical variables
    - Convert variables from one type to another
    - Familiarize with strings
Assignment 6:
    1- Work on your selected data set and covert a column of non-categorical type into a categorical type.
    2- Convert another column into a string type
    3- Submit your Pyhton Notebook file to Canvas
'''

# %%
# loading pandas library
import pandas as pd

# %%
# loading the dataset of state drug utilization 
state_drug = pd.read_csv('datasets/state_drug_utilization.csv')

# displaying the first 5 rows
state_drug.head()
# Out:
#    Unnamed: 0 Utilization Type State  Labeler Code  Product Code  \
# 0      128037             MCOU    MA         37205           137
# 1      491755             FFSU    FL         62756           763
# 2     2568076             FFSU    UT         46987           323
# 3      491263             FFSU    MN           781          5185
# 4      836489             FFSU    XX         51552           809
#
#    Package Size  Year  Quarter Product Name  Units Reimbursed  ...  \
# 0             5  2010        4   ARTIFICIAL            15.000  ...
# 1            88  2010        1    TORSEMIDE           255.000  ...
# 2            11  2010        2   Kadian Ora           120.000  ...
# 3             1  2010        4   LEVOTHYROX          1114.000  ...
# 4             6  2010        2   COLD CREAM           226.089  ...
#
#    Number of Prescriptions  Total Amount Reimbursed  \
# 0                        1                     4.08
# 1                        8                   103.33
# ...

# %%
# making a subset dataset from the original dataset
df = state_drug.iloc[10:21 , [6, 2, 8, 11, 12, 5]]
df.head()
# Out:
#     Year State Product Name  Number of Prescriptions  Total Amount Reimbursed  \
# 10  2010    CT    METFORMIN                        2                    45.33
# 11  2010    DC   PREDNISONE                        1                     9.36
# 12  2010    MT   CITALOPRAM                       13                   111.47
# 13  2010    NV     BACLOFEN                        4                    20.35
# 14  2010    MD    NAFTIN 1%                        6                   611.10
#
#     Package Size
# 10             1
# 11            15
# 12             1
# 13             6
# 14            30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 10 to 20
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     11 non-null     int64
#  1   State                    11 non-null     object
#  2   Product Name             11 non-null     object
#  3   Number of Prescriptions  11 non-null     int64
#  4   Total Amount Reimbursed  11 non-null     float64
#  5   Package Size             11 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 660.0+ bytes

# %%
# converting 'Package Size column from int64 to categorical type
df['Package Size'] = df['Package Size'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 10 to 20
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     11 non-null     int64
#  1   State                    11 non-null     object
#  2   Product Name             11 non-null     object
#  3   Number of Prescriptions  11 non-null     int64
#  4   Total Amount Reimbursed  11 non-null     float64
#  5   Package Size             11 non-null     category
# dtypes: category(1), float64(1), int64(2), object(2)
# memory usage: 803.0+ bytes

# %%
# converting year datatype from object to datetime
df['Year'] = pd.to_datetime(df['Year'])

# %%
df.dtypes
# Out:
# Year                       datetime64[ns]
# State                              object
# Product Name                       object
# Number of Prescriptions             int64
# Total Amount Reimbursed           float64
# Package Size                     category
# dtype: object

# %%
# converting 'number of prescription' column from int64 to string type
df['Number of Prescriptions'] = df['Number of Prescriptions'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 10 to 20
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     11 non-null     datetime64[ns]
#  1   State                    11 non-null     object
#  2   Product Name             11 non-null     object
#  3   Number of Prescriptions  11 non-null     object
#  4   Total Amount Reimbursed  11 non-null     float64
#  5   Package Size             11 non-null     category
# dtypes: category(1), datetime64[ns](1), float64(1), object(3)
# memory usage: 803.0+ bytes

# %%
df.head()
# Out:
#                             Year State Product Name Number of Prescriptions  \
# 10 1970-01-01 00:00:00.000002010    CT    METFORMIN                       2
# 11 1970-01-01 00:00:00.000002010    DC   PREDNISONE                       1
# 12 1970-01-01 00:00:00.000002010    MT   CITALOPRAM                      13
# 13 1970-01-01 00:00:00.000002010    NV     BACLOFEN                       4
# 14 1970-01-01 00:00:00.000002010    MD    NAFTIN 1%                       6
#
#     Total Amount Reimbursed Package Size
# 10                    45.33            1
# 11                     9.36           15
# 12                   111.47            1
# 13                    20.35            6
# 14                   611.10           30

# %%
df[['Total Amount Reimbursed']].plot();

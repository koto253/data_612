# %%
import pandas as pd

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/chendaniely/\
pandas_for_everyone/master/data/gapminder.tsv', sep='\t')

df2 = pd.read_csv('State_Drug_Utilization_Data_2010.csv')

df3 = pd.read_csv('stocks_yahoo.csv', low_memory=False)

df4 = pd.read_csv('Teams.csv')

# %%
df2
# Out:
#         Unnamed: 0 Utilization Type State  Labeler Code  Product Code  \
# 0           128037             MCOU    MA         37205           137
# 1           491755             FFSU    FL         62756           763
# 2          2568076             FFSU    UT         46987           323
# 3           491263             FFSU    MN           781          5185
# 4           836489             FFSU    XX         51552           809
# ...            ...              ...   ...           ...           ...
# 156215     2752214             MCOU    XX         63868            17
# 156216     2519195             MCOU    MI           121           489
# 156217      815768             MCOU    MD         60432           133
# 156218     2029158             FFSU    DE            88          1109
# 156219     2799238             FFSU    DE            29          1527
#
#         Package Size  Year  Quarter Product Name  Units Reimbursed  ...  \
# ...

# %%
# axis= 0 is row wise concatenation 
# axis=1 is column wise concatenation
concatenated =  pd.concat([df1, df2], )

# %%
concatenated.to_csv('concatenated.csv')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 946E-965C
#
#  Directory of c:\Users\x-ibah\Desktop\Franklin\data_612
#
# 03/08/2024  08:47 PM    <DIR>          .
# 03/08/2024  08:47 PM    <DIR>          ..
# 03/05/2024  11:43 PM    <DIR>          .ipynb_checkpoints
# 03/06/2024  08:28 PM             2,002 assignment_1_ismael_bah.ipynb
# 03/08/2024  05:03 PM            67,521 assignment_2.ipynb
# 03/05/2024  04:44 PM            62,317 assignment_2-Copy1.ipynb
# 03/05/2024  08:51 PM             1,923 assignment_3.ipynb
# 03/08/2024  08:47 PM        26,746,913 concatenated.csv
# 02/20/2024  04:54 PM         1,959,977 module 1.pdf
# 03/08/2024  07:46 PM                 0 part_II.ipynb
# 03/06/2024  12:13 AM            13,846 practicing chap 1 part I .ipynb
# 03/08/2024  07:58 PM        22,382,139 State_Drug_Utilization_Data_2010.csv
# 02/28/2024  04:49 PM        13,410,022 stocks_yahoo.csv
# 03/08/2024  07:58 PM           263,544 Teams.csv
# ...
